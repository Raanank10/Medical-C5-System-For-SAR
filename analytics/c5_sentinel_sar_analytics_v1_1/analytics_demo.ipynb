# %% [markdown]
# # C5 Sentinel-SAR Analytics Demo v1.1
# Run the seed script, compute KPIs, and generate an AAR HTML report.

# %%
from pathlib import Path
import sys
sys.path.insert(0, str(Path('.').resolve()))
from seed_demo_db import main as seed_db
from db import DB
from kpis import KPIEngine
from report import ReportGenerator
db_path = seed_db()
db = DB(db_path)
kpi = KPIEngine(db)

# %%
kpi.command_summary()

# %%
kpi.patients_missing_full_vitals()

# %%
kpi.stockout_risk()

# %%
out = ReportGenerator(kpi).save('aar_report_v1_1.html')
out
